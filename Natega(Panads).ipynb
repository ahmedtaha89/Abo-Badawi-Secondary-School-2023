# %%
import pandas as pd

# %%
file_name = pd.read_csv('Final_Results.csv')

# %%
file_name.head(10)
# Out:
#    الترتيب  رقم الجلوس                                الاسم      الشعبة  \
# 0        1     1457730      محمود احمد محمود علي محمد سلامة  عملي رياضة
# 1        2     1459586  رحمه ابراهيم عبدالعزيز موسى العيسوي   عملي علوم
# 2        3     1459568               ايه ايمن علي صالح يوسف   عملي علوم
# 3        4     1459585   رحمه ابراهيم عبد القادر السيد احمد   عملي علوم
# 4        5     1459587     رحمه احمد جمال الدين مصطفى الأبس   عملي علوم
# 5        6     1459577          خلود محمد حسين على فخرالدين   عملي علوم
# 6        7     1459564  اماني عبدالحليم عبدالفتاح عبدالحليم   عملي علوم
# 7        8     1459543              مرام محمد صادق جمعه حسن        أدبي
# 8        9     1457705     محمود احمد عبدالمنعم مصطفى متولى   عملي علوم
# 9       10     1459589       رحمه هيثم محمد احمد عبدالمقصود   عملي علوم
#
#    المجموع  النسبة حالة الطالب  عربي  اللغة الأجنبية الثانية  \
# 0      392  95.61%        ناجح  73.5                    48.5
# ...

# %%
file_name.tail(10)
# Out:
#      الترتيب  رقم الجلوس                             الاسم      الشعبة  \
# 205      206     1459542     لبنى رضا على ابراهيم القبلاوي        أدبي
# 206      207     1457645      احمد رضا عبداللطيف عبدالحافظ        أدبي
# 207      208     1459653    منى المتولى حسن الغريب ابراهيم  عملي رياضة
# 208      209     1459579   دعاء محمد السيد فايد السيد محمد   عملي علوم
# 209      210     1459650    اسماء السيد صلاح السيد المغازي  عملي رياضة
# 210      211     1459654      ندى ذكي عبدالوهاب محمد السيد  عملي رياضة
# 211      212     1457672        زياد فرج السعيد فرج السعيد   عملي علوم
# 212      213     1459630  نوران نجاح انور عبد العال البيلى   عملي علوم
# 213      214     1459572       بشرى حامد ابراهيم سعيد ناصر   عملي علوم
# 214      215     1459548           نسمه امن يوسف محمد يوسف        أدبي
#
#      المجموع  النسبة حالة الطالب  عربي  اللغة الأجنبية الثانية  \
# 205      235  57.20%        ناجح  40.5                    43.0
# ...

# %%
file_name['الاسم']
# Out:
# 0          محمود احمد محمود علي محمد سلامة
# 1      رحمه ابراهيم عبدالعزيز موسى العيسوي
# 2                   ايه ايمن علي صالح يوسف
# 3       رحمه ابراهيم عبد القادر السيد احمد
# 4         رحمه احمد جمال الدين مصطفى الأبس
#                       ...
# 210           ندى ذكي عبدالوهاب محمد السيد
# 211             زياد فرج السعيد فرج السعيد
# 212       نوران نجاح انور عبد العال البيلى
# 213            بشرى حامد ابراهيم سعيد ناصر
# 214                نسمه امن يوسف محمد يوسف
# Name: الاسم, Length: 215, dtype: object

# %%
file_name.iloc[2]
# Out:
# الترتيب                                         3
# رقم الجلوس                                1459568
# الاسم                      ايه ايمن علي صالح يوسف
# الشعبة                                  عملي علوم
# المجموع                                       379
# النسبة                                     92.30%
# حالة الطالب                                  ناجح
# عربي                                         79.5
# اللغة الأجنبية الثانية                       48.5
# اللغة الأجنبية الثانية2                      39.5
# التاريخ                                       0.0
# الجغرافيا                                     0.0
# الفلسفة والمنطق                               0.0
# علم النفس والاجتماع                             0
# الكيمياء                                     55.0
# الأحياء                                      45.0
# الجيولوجيا وعلوم البيئة                      58.0
# الفيزياء                                     53.0
# مجموع الرياضيات البحتة                        0.0
# ...

# %%
file_name.loc[2]
# Out:
# الترتيب                                         3
# رقم الجلوس                                1459568
# الاسم                      ايه ايمن علي صالح يوسف
# الشعبة                                  عملي علوم
# المجموع                                       379
# النسبة                                     92.30%
# حالة الطالب                                  ناجح
# عربي                                         79.5
# اللغة الأجنبية الثانية                       48.5
# اللغة الأجنبية الثانية2                      39.5
# التاريخ                                       0.0
# الجغرافيا                                     0.0
# الفلسفة والمنطق                               0.0
# علم النفس والاجتماع                             0
# الكيمياء                                     55.0
# الأحياء                                      45.0
# الجيولوجيا وعلوم البيئة                      58.0
# الفيزياء                                     53.0
# مجموع الرياضيات البحتة                        0.0
# ...

# %%
file_name.loc[55, 'الاسم']
# Out:
# 'سامي سعد احمد سعد عثمان'

# %%
file_name.loc[:10, ['الاسم','الشعبة','المجموع']]
# Out:
#                                   الاسم      الشعبة  المجموع
# 0       محمود احمد محمود علي محمد سلامة  عملي رياضة      392
# 1   رحمه ابراهيم عبدالعزيز موسى العيسوي   عملي علوم      380
# 2                ايه ايمن علي صالح يوسف   عملي علوم      379
# 3    رحمه ابراهيم عبد القادر السيد احمد   عملي علوم      375
# 4      رحمه احمد جمال الدين مصطفى الأبس   عملي علوم      373
# 5           خلود محمد حسين على فخرالدين   عملي علوم      372
# 6   اماني عبدالحليم عبدالفتاح عبدالحليم   عملي علوم      371
# 7               مرام محمد صادق جمعه حسن        أدبي      371
# 8      محمود احمد عبدالمنعم مصطفى متولى   عملي علوم      369
# 9        رحمه هيثم محمد احمد عبدالمقصود   عملي علوم      362
# 10         مصطفى حمادة عطية محمود السيد   عملي علوم      359

# %%
file_name.loc[(file_name.النسبة>'90.00%')]
# Out:
#    الترتيب  رقم الجلوس                                الاسم      الشعبة  \
# 0        1     1457730      محمود احمد محمود علي محمد سلامة  عملي رياضة
# 1        2     1459586  رحمه ابراهيم عبدالعزيز موسى العيسوي   عملي علوم
# 2        3     1459568               ايه ايمن علي صالح يوسف   عملي علوم
# 3        4     1459585   رحمه ابراهيم عبد القادر السيد احمد   عملي علوم
# 4        5     1459587     رحمه احمد جمال الدين مصطفى الأبس   عملي علوم
# 5        6     1459577          خلود محمد حسين على فخرالدين   عملي علوم
# 6        7     1459564  اماني عبدالحليم عبدالفتاح عبدالحليم   عملي علوم
# 7        8     1459543              مرام محمد صادق جمعه حسن        أدبي
#
#    المجموع  النسبة حالة الطالب  عربي  اللغة الأجنبية الثانية  \
# 0      392  95.61%        ناجح  73.5                    48.5
# 1      380  92.70%        ناجح  76.5                    49.5
# 2      379  92.30%        ناجح  79.5                    48.5
# 3      375  91.50%        ناجح  71.5                    48.0
# ...

# %%
max_pre=file_name.النسبة.max()
min_pre=file_name.النسبة.min()
print(max_pre)
print(min_pre)
# Out:
# 95.61%
# 43.10%

# %%
avg_pre = file_name.المجموع.mean()
print(f'{avg_pre:.2f}')
# Out:
# 294.07
